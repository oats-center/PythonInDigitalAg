# %% [markdown]
# ## Practise Workbook 2

# %% [markdown]
# #### **Task 1**: United states wheat yield trends as a plotting example.
#  - Data was obtained from the United States Department of Agriculture: <a href="https://quickstats.nass.usda.gov/" target="_blank">Quick Stats</a> (The USDA's National Ag Statistics Service -- we will make more use of this in the lab later).
#  - The **python graph gallery** is a useful collection of charts written using the matplotlib package in python https://www.python-graph-gallery.com/ .

# %%
import numpy as np
# The years for which we have average wheat yield data.
dates = np.array([2021, 2020, 2019, 2018, 2017, 2016, 2015, 2014, 2013, 2012, 2011, 2010, 2009, 2008, 2007, 2006, 2005, 2004, 2003, 2002, 2001, 2000,1999, 1998, 1997, 1996, 1995, 1994, 1993, 1992, 1991, 1990, 1989, 1988, 1987, 1986, 1985, 1984, 1983, 1982, 1981, 1980, 1979, 1978, 1977, 1976, 1975, 1974, 1973, 1972, 1971, 1970, 1969, 1968, 1967,1966, 1965, 1964, 1963, 1962, 1961, 1960, 1959, 1958, 1957, 1956, 1955, 1954, 1953, 1952, 1951, 1950, 1949, 1948, 1947, 1946, 1945,1944, 1943, 1942, 1941, 1940, 1939, 1938, 1937, 1936, 1935, 1934, 1933, 1932, 1931, 1930, 1929, 1928, 1927, 1926, 1925, 1924, 1923,1922, 1921, 1920, 1919, 1918, 1917, 1916, 1915, 1914, 1913, 1912,1911, 1910, 1909, 1908, 1907, 1906, 1905, 1904, 1903, 1902, 1901,1900, 1899, 1898, 1897, 1896, 1895, 1894, 1893, 1892, 1891, 1890,1889, 1888, 1887, 1886, 1885, 1884, 1883, 1882, 1881, 1880, 1879,1878, 1877, 1876, 1875, 1874, 1873, 1872, 1871, 1870, 1869, 1868, 1867, 1866])
dates
# Out:
# array([2021, 2020, 2019, 2018, 2017, 2016, 2015, 2014, 2013, 2012, 2011,
#        2010, 2009, 2008, 2007, 2006, 2005, 2004, 2003, 2002, 2001, 2000,
#        1999, 1998, 1997, 1996, 1995, 1994, 1993, 1992, 1991, 1990, 1989,
#        1988, 1987, 1986, 1985, 1984, 1983, 1982, 1981, 1980, 1979, 1978,
#        1977, 1976, 1975, 1974, 1973, 1972, 1971, 1970, 1969, 1968, 1967,
#        1966, 1965, 1964, 1963, 1962, 1961, 1960, 1959, 1958, 1957, 1956,
#        1955, 1954, 1953, 1952, 1951, 1950, 1949, 1948, 1947, 1946, 1945,
#        1944, 1943, 1942, 1941, 1940, 1939, 1938, 1937, 1936, 1935, 1934,
#        1933, 1932, 1931, 1930, 1929, 1928, 1927, 1926, 1925, 1924, 1923,
#        1922, 1921, 1920, 1919, 1918, 1917, 1916, 1915, 1914, 1913, 1912,
#        1911, 1910, 1909, 1908, 1907, 1906, 1905, 1904, 1903, 1902, 1901,
#        1900, 1899, 1898, 1897, 1896, 1895, 1894, 1893, 1892, 1891, 1890,
#        1889, 1888, 1887, 1886, 1885, 1884, 1883, 1882, 1881, 1880, 1879,
# ...

# %%
# The average wheat yield data in the order to line up with the corresponding years.
# ...

# %%
import matplotlib.pyplot as plt
# Plotting the wheat yield trend
fig = plt.figure()
plt.style.use('classic')
plt.plot(dates, yields)
plt.title("United States Average Wheat Yield by Year")
plt.xlabel("Year")
plt.ylabel("Yield in bushels per acre")
plt.grid()

# %% [markdown]
# #### **`Assesment task 2.1`**: Navigate to the python graph gallery and plot the histogram for yield data and show the mean and median of the yields on a histogram plot. Write a markdown below your code to explain
#  - the number of bins selected
#  - the mean and
#  - the median
# of the yield data.
#
#  *add median/mean line in the Yield in bushels per acre vs Year plot, to challenge yourself !!*

# %% [markdown]
# ####  **Graphical visualization using python matplotlib package**
# Here are two inforgraphs for revising the functions we all know.
# ![image.png](attachment:image.png)      ![image.png](attachment:image-2.png)

# %%
x = np.linspace(0, 10, 100)
fig2 = plt.figure()
plt.style.use('seaborn-dark-palette')
plt.plot(x, np.sin(x))
plt.plot(x, np.cos(x))
# Out:
# C:\Users\jha16\AppData\Local\Temp\ipykernel_33616\1000985627.py:3: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use('seaborn-dark-palette')

# %% [markdown]
# #### **Task 2:** Plot multiple plots in the same figure using Matplotlib.
# Add other even power functions to the same figure below. Try adding a quadratic polynomial $(y=x^2 + 5x + 2)$.
#   - You may note, adding more number of x values within a given range creates a smoother curve. This is useful in statistical analysis.

# %%
# Import libraries
import matplotlib.pyplot as plt
import numpy as np
 
x = np.linspace(-6, 6, 100)
x1= np.linspace(-6, 6, 10)
fig = plt.figure(figsize = (14, 8))
 
# Plot y = cos(x)
y = x*x
plt.plot(x, y, 'b', linewidth=2,label ='square')
 
y1 = x1*x1 -1
plt.plot(x1, y1, 'red', linewidth=2,label ='square')
# Add features to our figure
plt.legend()
plt.grid(True, linestyle =':')
plt.xlim([-6, 6])
plt.ylim([-4, 4])
 
plt.title('curve for polynomial with even powers')
plt.xlabel('x-axis')
plt.ylabel('y-axis')
 
# Show plot
plt.show()

# %% [markdown]
# **`Assesment task 2.2`** : Draw a plot with odd functions like you did for the even powered functions. Try absolute function (it is shown in the inforgraph) and choose a good range of x values for better visualization. you can use this polynomial $(y=x^5 + 5x^2 + 2)$ .  Use x range as[-10,10].
#     - You may note, adding more number of x values within a given range creates a smoother curve. This is useful in statistical analysis. Try to make a smooth curve.

# %% [markdown]
# #### **Exploring ACIS / PRISM weather data and GDU curves using matplotlib**

# %%
import requests
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt # This is just so we don't have to type "matplotlib.pyplot" all the time.

# %%
# Setup some plotting styles 
#%matplotlib notebook
# %matplotlib inline

import seaborn as sns
sns.set_theme()

plt.rc('font', size=20)          # controls default text sizes
plt.rc('axes', titlesize=20)     # fontsize of the axes title
plt.rc('axes', labelsize=20)    # fontsize of the x and y labels
plt.rc('xtick', labelsize=20)    # fontsize of the tick labels
plt.rc('ytick', labelsize=20)    # fontsize of the tick labels
plt.rc('legend', fontsize=20)    # legend fontsize
plt.rc('figure', titlesize=20, figsize=(15, 8))  # fontsize of the figure title

# %% [markdown]
# Let us start by grabbing some ACIS weather data for a field at Purdue's [ACRE farm](https://www.google.com/maps/place/40%C2%B028'27.2%22N+86%C2%B059'43.7%22W/@40.4742259,-86.9975974,1242m/data=!3m1!1e3!4m5!3m4!1s0x0:0x0!8m2!3d40.4742222!4d-86.9954722). That is GPS coordinate: (40.4742259,-86.9975974).
#
# We will grab all the _historical_ data that ACIS/PRISM has available. Let's ignore _this_ years data for now (because it is incomplete).
#
# It is okay if you don't understand all this code right now. We will spend some time getting used to Python/Pandas before we compute the GDU curves.

# %%
# GPS coordinates of interest
lat = 40.4742259
lon = -86.9975974

# PRISM usally goes back to 1981
sdate = "1981-01-01"
edate = "2020-12-31"

# Make ACIS API request
w = requests.post('http://data.rcc-acis.org/GridData', json={
    "loc": f"{lon}, {lat}",
    "sdate": sdate,
    "edate": edate,
    "grid": "21",   # "21" is PRISM
    "elems": [
        { "name":"maxt", "interval":"dly", "units":"degreeF" },
        { "name":"mint", "interval":"dly", "units":"degreeF" },
        { "name":"pcpn", "interval":"dly", "units":"inch" }
    ]
    
})

# Parse the JSON response to a Python datatypes
w = w.json()

# %%
# Convert the raw Python map to a Pandas DataFrame
w = pd.DataFrame(w['data'], columns=['date', 'maxt', 'mint', 'pcpn'])

w.to_csv("acre_weather_data.csv")

# %%
# Convert the date "string" into a real Pandas date object (enables some Pandas niceties)
w['date'] = pd.to_datetime(w['date'])

# Tell Pandas to use the "date" columns as the index. Basically this means it will be easy 
# to select data from the DataFrame by date and date range.
w.set_index('date', inplace=True)

# %%
t_max=84
t_base=50
w["maxt_gd"]=w["maxt"]
w["mint_gd"]=w["mint"]
w.loc[w.maxt_gd > t_max, 'maxt_gd'] = t_max

# Save the daily GDU totals back to the DataFrame as a new column
w['gdu'] = (w.maxt_gd + w.mint_gd) / 2 - t_base
# Negative GDUs are assumed to be zero ... that is a colder day doesn't reduce the growth

w.loc[w.gdu < 0, 'gdu'] = 0 

w.describe()
# Out:
#                maxt          mint          pcpn       maxt_gd       mint_gd  \
# count  14610.000000  14610.000000  14610.000000  14610.000000  14610.000000
# mean      61.301095     41.223477      0.107115     60.668994     41.223477
# std       21.006094     18.941977      0.289385     20.198551     18.941977
# min      -11.000000    -24.000000      0.000000    -11.000000    -24.000000
# 25%       44.000000     28.000000      0.000000     44.000000     28.000000
# 50%       64.000000     42.000000      0.000000     64.000000     42.000000
# 75%       80.000000     57.000000      0.050000     80.000000     57.000000
# max      103.000000     77.000000      4.490000     84.000000     77.000000
#
#                 gdu
# count  14610.000000
# mean       8.768994
# std        9.984451
# min        0.000000
# 25%        0.000000
# 50%        3.000000
# 75%       18.500000
# max       30.500000

# %%
# Let's "copy" the DataFrame so we don't break the data for the rest of the notebook
w_copy = w.copy()

# Compute average temp and save back to the data frame
w_copy['avgt'] = (w_copy.mint + w_copy.maxt) / 2

w_copy.avgt
# Out:
# date
# 1981-01-01    32.0
# 1981-01-02    25.5
# 1981-01-03    25.0
# 1981-01-04    11.0
# 1981-01-05     5.0
#               ...
# 2020-12-27    28.0
# 2020-12-28    38.5
# 2020-12-29    23.5
# 2020-12-30    28.5
# 2020-12-31    34.0
# Name: avgt, Length: 14610, dtype: float64

# %% [markdown]
# #### **Task 3**: Getting comfortable with Matplotlib
#
#
# Plot of all the max temperature data in one plot.

# %%
# Matplotlib combined with Pandas makes plotting really easy!
# Note: Matplotlib was able to determine the correct x-axis based on the DataFrame's index (in this case, date)
plt.plot(w.maxt)

# We can improve the plot by adding labels, title, and tick rotation (the date strings are long)
plt.ylabel('Temperature (F)')
plt.title('Max temperature over time')
plt.xticks(rotation=25)

# A "tight layout" just reduces the amount of white space in the figure. A bit noisier but also larger plots.
plt.tight_layout()
plt.show()

# %%
# Matplotlib combined with Pandas makes plotting really easy!
# Note: Matplotlib was able to determine the correct x-axis based on the DataFrame's index (in this case, date)
plt.plot(w.gdu)

# We can improve the plot by adding labels, title, and tick rotation (the date strings are long)
plt.ylabel('gdd(Tbase=50F)')
plt.title('GDD over time')
plt.xticks(rotation=25)

# A "tight layout" just reduces the amount of white space in the figure. A bit noisier but also larger plots.
plt.tight_layout()
plt.show()

# %% [markdown]
# **`Assesment task 2.3`**: Plotting multiple lines
#
# Plot both the 2020 minimum and maximum temperatures as separate lines on the same plot. This is the expected result.
#
# <img align="center" src='Figs/assesment2.3.png' width="800"/>

# %%
# We store the slice into 'w' as w20 for convenience (we will use it over and over again)
w20 = w['2020-01-01':'2020-12-31']
fig,ax=plt.subplots()
ax1=ax
ax1 = ax.twinx()

# Calling `plot` multiple times add additional lines to the same figure
ax.plot(w20.maxt)
ax.plot(w20.mint)
ax1.plot(w20.gdu, color="red")


# Add a legend to distinguish between the two curves
plt.title('Temperature and Growing Degree days(GDD) over time in 2020')

ax.set_ylabel('Temperature (F)')
ax1.set_ylabel('GDD(Tbase=50F)',fontsize=14)
#ax.xticks(rotation=25)
ax.legend(['Max Temp', 'Min Temp', 'gdu'], loc="upper left")
ax1.legend(['GDD'])
plt.tight_layout()
plt.show()

# %% [markdown]
# **`Assesment task 2.4`**: Plotting two plots on one figure
#
# Plot both the 2020 minimum and maximum temperatures as separate lines on one plot and 2020 precipitation on the other. Make the two plots stack vertically and share the same time axis. this is the expected graph.
#
# <img align="center" src='Figs/assesment2.4.png' width="800"/>

# %%
### Put two plots on one figure

# The `subplot` command allows us to slice up one image and draw multiple independent figures into each slice
# In this case, we are slicing the image into 2 rows and 1 column. We select the first slice.
ax = plt.subplot(2, 1, 1)
plt.plot(w20.maxt)
plt.plot(w20.mint)

plt.legend(['Max Temp', 'Min Temp'])
plt.ylabel('Temperature (F)')
plt.title('Max temperature over time')
plt.xticks(rotation=25)

# Now we select the second slice. Notice we share the x-axis. This is so when you interact with the either plot
# the other plot is automatically adjusted to the same scale.
plt.subplot(2, 1, 2, sharex=ax)
plt.plot(w20.pcpn)

plt.ylabel('Precipitation (in)')
plt.xticks(rotation=25)

plt.tight_layout()
plt.show()
